# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelGui/Pandas_learining/blob/main/2_pandas_%E4%B8%AA%E6%80%A7%E5%8C%96%E6%98%BE%E7%A4%BA%E8%AE%BE%E7%BD%AE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas 进阶修炼 ｜早起Python
# <br>
#
# **本习题由公众号【早起Python & 可视化图鉴】 原创，转载及其他形式合作请与我们联系（微信号`sshs321`)，未经授权严禁搬运及二次创作，侵权必究！**
#
#
#
# 本习题基于 `pandas` 版本 `1.1.3`，所有内容应当在 `Jupyter Notebook` 中执行以获得最佳效果。
#
# 不同版本之间写法可能会有少许不同，如若碰到此情况，你应该学会如何自行检索解决。

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2 - pandas 个性化显示设置
# <br>
#
# 在使用 `pandas` 时，有时默认的配置方案并不能让我们舒服的进行数据分析。
#
# 幸运的是，`pandas` 也支持我们 <font color=#E36C07>**自定义显示、样式等个性化操作**</font>。
#
# 本节将部分常用的设置整理为习题形式，<font color=#E36C07>  **所有操作答案拿走即用。既可以刷一遍来了解有这样那样的设置，也可以保存用于速查手册** </font>
#
# 注意：本习题中未提及的配置可以点击查阅 `pandas` 👉 [**官方文档对应文章**](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html)

# %% [markdown]
# ## 初始化
#
# <br>
#
# 该 `Notebook` 版本为**纯习题版**
#
# 如果需要答案或者提示，可以微信搜索公众号「早起Python」获取！

# %% [markdown]
# ## 加载数据

# %% [markdown]
# 导入 `pandas` 并读取当前目录下 `csv` 数据(`data.csv`)

# %%
import pandas as pd
path = "/content/drive/MyDrive/Pandas_Advanced_Exercise-main/2 - 个性化显示设置/data.csv"

# %%
data = pd.read_csv(path)
data
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...  NaN      0       0       0              NaN
# 1          建模  ...  NaN      0       0       0              NaN
# 2        数据分析  ...  NaN      0       0       0              NaN
# 3        数据分析  ...  NaN      0       0       0              NaN
# 4        数据分析  ...  NaN      0       0       0              NaN
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                     NaN         0      0                   []         False
# 1                     NaN         0      0                   []         False
# 2                     NaN         0      0                   []         False
# 3                     NaN         0      0                   []          True
# 4                     NaN         0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                   NaN         0      0                   []         False
# 101                   NaN         0      0                   []         False
# 102                   NaN         0      0                   []         False
# 103                   NaN         0      0                   []          True
# 104                   NaN         0      0                   []          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ## 2-1 基于 option 修改显示设置
# <br>
#
# 在 `pandas` 中有一个 `option` 系统，可以通过 `set_option`方法进行进阶显示选项设置。
#
# 本小节主要整理了一些基于 `option` 修改数据显示的设置。
#
# 注意【**基于 option 修改显示设置**】并未修改数据，仅是在原有数据基础上优化显示状态，随时可以通过重置选项重置全部设置，恢复数据默认显示状态。

# %% [markdown]
# ### 1 显示全部列
#
# <br>
# 如下图所示👇，直接查看 `data` 会发现，由于数据维度较大，部分行列会被折叠，显示为`...`，现在需要显示全部的列方便预览。
#
# ![](http://liuzaoqi.oss-cn-beijing.aliyuncs.com/2021/08/19/16293397012946.jpg?域名/sample.jpg?x-oss-process=style/stylename)

# %% [markdown]
# 在下面的 cell 中输入你的解决方案，并在最后执行 `data.head()`以检查你的答案是否正确解决问题。

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None) #显示完整的行
# pd.set_option('display.expand_frame_repr', False) #设置不折叠数据
data.head(3)
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 1     5204912         数据建模      50735    150-500人            电商           B轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
#
#                    companyLabelList  firstType secondType thirdType  \
# 0  ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析
# 1  ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模
# 2  ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析
#
#                     skillLables                            positionLables  \
# 0  ['SQL', '数据库', '数据运营', 'BI']  ['电商', '社交', 'SQL', '数据库', '数据运营', 'BI']
# 1                ['算法', '数据架构']                            ['算法', '数据架构']
# 2        ['数据库', '数据分析', 'SQL']                            ['数据库', 'SQL']
#
#                              industryLables       createTime formatCreateTime  \
# 0  ['电商', '社交', 'SQL', '数据库', '数据运营', 'BI']  2020/3/16 11:00          11:00发布
# 1                                        []  2020/3/16 11:08          11:08发布
# 2                                        []  2020/3/16 10:33          10:33发布
#
#   district    businessZones  salary workYear jobNature education  \
# 0      余杭区           ['仓前']   37500     1-3年        全职        本科
# 1      滨江区     ['西兴', '长河']   15000     3-5年        全职        本科
# 2      江干区  ['四季青', '钱江新城']    3500     1-3年        全职        本科
#
#      positionAdvantage   imState        lastLogin  publisherId  approve  \
# 0  五险一金、弹性工作、带薪年假、年度体检     today  2020/3/16 11:00     12022406        1
# 1       六险一金,定期体检,丰厚年终  disabled  2020/3/16 11:08      5491688        1
# 2   五险一金 周末双休 不加班 节日福利     today  2020/3/16 10:33      5322583        1
#
#   subwayline stationname                linestaion   latitude   longitude  \
# 0        NaN         NaN                       NaN  30.278421  120.005922
# 1        NaN         NaN                       NaN  30.188041  120.201179
# 2        4号线         江锦路  4号线_城星路;4号线_市民中心;4号线_江锦路  30.241521  120.212539
#
#   hitags  resumeProcessRate  resumeProcessDay  score  newScore  matchScore  \
# 0    NaN                 50                 1    233         0   15.101875
# 1    NaN                 23                 1    176         0   32.559414
# 2    NaN                 11                 4     80         0   14.972357
#
#    matchScoreExplain  query  explain  isSchoolJob  adWord  plus  pcShow  \
# 0                NaN    NaN      NaN            0       0   NaN       0
# 1                NaN    NaN      NaN            0       0   NaN       0
# 2                NaN    NaN      NaN            0       0   NaN       0
#
#    appShow  deliver  gradeDescription  promotionScoreExplain  isHotHire  \
# 0        0        0               NaN                    NaN          0
# 1        0        0               NaN                    NaN          0
# 2        0        0               NaN                    NaN          0
#
#    count aggregatePositionIds  famousCompany
# 0      0                   []          False
# 1      0                   []          False
# 2      0                   []          False

# %% [markdown]
# ### 2 显示指定行/列
#
# <br>
#
# 指定让 `data` 在预览时显示10列，7行

# %%
data_show = data.iloc[0:7,  0:10]
data_show
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 1     5204912         数据建模      50735    150-500人            电商           B轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 3     6496141         数据分析      26564   500-2000人            电商        D轮及以上
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司
# 5     6882347         数据分析      94826     50-150人      移动互联网,社交           B轮
# 6     6841659         数据分析     348784     50-150人      移动互联网,电商           A轮
#
#                     companyLabelList  firstType secondType thirdType
# 0   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析
# 1   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模
# 2   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析
# 3  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析
# 4   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析
# 5   ['股票期权', '扁平管理', '五险一金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析
# 6   ['大牛团队', '扁平管理', '年底双薪', '股票期权']  产品|需求|项目类       数据分析      数据分析

# %%
pd.set_option('display.max_rows', 7)
pd.set_option('display.max_columns', 10)
data
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# ..          ...                    ...        ...         ...           ...
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#      ... promotionScoreExplain isHotHire count aggregatePositionIds  \
# 0    ...                   NaN         0     0                   []
# 1    ...                   NaN         0     0                   []
# 2    ...                   NaN         0     0                   []
# ..   ...                   ...       ...   ...                  ...
# 102  ...                   NaN         0     0                   []
# 103  ...                   NaN         0     0                   []
# 104  ...                   NaN         0     0                   []
#
#     famousCompany
# 0           False
# 1           False
# 2           False
# ..            ...
# 102         False
# 103          True
# 104          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ### 3 还原行/列显示数
#
# <br>
# 还原上面的显示设置

# %%
pd.reset_option('max_rows')
pd.reset_option('max_columns')

# %% [markdown]
# ### 4 修改每列最大字符宽度
#
# <br>
#
# 即每列最多显示的字符长度，例如【每列最多显示10个字符，多余的会变成`...`】

# %%
pd.set_option('display.max_colwidth', 10)
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0    6802721        数据分析       475770    50-150人    移动互联网,电商            A轮
# 1    5204912        数据建模        50735   150-500人          电商            B轮
# 2    6877668        数据分析       100125    2000人以上   移动互联网,...          上市公司
# 3    6496141        数据分析        26564  500-2000人          电商         D轮及以上
# 4    6467417        数据分析        29211    2000人以上       物流丨运输          上市公司
#
#   companyLabelList  firstType secondType thirdType  ... plus pcShow appShow  \
# 0  ['绩效奖金...        产品|需求|项目类       数据分析      数据分析  ...  NaN      0       0
# 1  ['年终奖金...        开发|测试|运维类       数据开发        建模  ...  NaN      0       0
# 2  ['节日礼物...        产品|需求|项目类       数据分析      数据分析  ...  NaN      0       0
# 3  ['生日趴'...        开发|测试|运维类       数据开发      数据分析  ...  NaN      0       0
# 4  ['技能培训...        产品|需求|项目类       数据分析      数据分析  ...  NaN      0       0
#
#   deliver gradeDescription promotionScoreExplain isHotHire  count  \
# 0       0        NaN              NaN                    0      0
# 1       0        NaN              NaN                    0      0
# 2       0        NaN              NaN                    0      0
# 3       0        NaN              NaN                    0      0
# 4       0        NaN              NaN                    0      0
#
#   aggregatePositionIds famousCompany
# 0         []                False
# 1         []                False
# 2         []                False
# 3         []                 True
# 4         []                 True
#
# [5 rows x 52 columns]

# %% [markdown]
# ### 5 修改小数点精度
#
# <br>
#
# 修改默认显示精度为小数点后5位

# %%
pd.set_option('display.float_format', '{:,.5f}'.format)

# %% [markdown]
# ### 6 还原所有显示设置

# %% [markdown]
# 还原上面的全部显示设置

# %%
pd.reset_option("^display")
# Out:
# <ipython-input-16-9993e1b881b6>:1: FutureWarning: column_space is deprecated and will be removed in a future version. Use df.to_string(col_space=...) instead.
#   pd.reset_option("^display")

# %% [markdown]
# ## 2-2 更多 option 相关设置

# %% [markdown]
# ### 7 忽略警告
# <br>
#
# 取消`pandas`相关`warning`提示

# %% [markdown]
# ### 8 设置数值显示条件

# %% [markdown]
# 如果数值小于 20 则显示为0

# %%
pd.set_option('chop_threshold', 20)

# %% [markdown]
# ### 9 让 pandas 支持 LaTex

# %% [markdown]
# 让`dataframe`中内容支持 `Latex` 显示（需要使用`$$`包住）

# %% [markdown]
# ### 10 修改默认绘图引擎
#
# 修改`pandas`默认绘图引擎为`plotly`（需要提前安装好`plotly`）

# %% [markdown]
# ### 11 还原所有 option 设置

# %% [markdown]
# 还原上面全部 option 设置

# %%
pd.reset_option("all")
# Out:
# <ipython-input-18-815ccf52250a>:1: FutureWarning: column_space is deprecated and will be removed in a future version. Use df.to_string(col_space=...) instead.
#   pd.reset_option("all")
# <ipython-input-18-815ccf52250a>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   pd.reset_option("all")
# <ipython-input-18-815ccf52250a>:1: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   pd.reset_option("all")

# %% [markdown]
# ### 彩蛋

# %% [markdown]
# 如何设置在预览数据时，不换行显示每列内容？
#
# > Indented block
#
#
#
# ![](http://liuzaoqi.oss-cn-beijing.aliyuncs.com/2021/08/19/16293394983242.jpg?域名/sample.jpg?x-oss-process=style/stylename)

# %%
pd.set_option('display.width', 5000)
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage                   companyLabelList  firstType secondType thirdType  ... plus pcShow appShow deliver gradeDescription promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...  NaN      0       0       0              NaN                   NaN         0      0                   []         False
# 1     5204912         数据建模      50735    150-500人            电商           B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...  NaN      0       0       0              NaN                   NaN         0      0                   []         False
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...  NaN      0       0       0              NaN                   NaN         0      0                   []         False
# 3     6496141         数据分析      26564   500-2000人            电商        D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...  NaN      0       0       0              NaN                   NaN         0      0                   []          True
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...  NaN      0       0       0              NaN                   NaN         0      0                   []          True
#
# [5 rows x 52 columns]

# %% [markdown]
# ## 2-3 基于 style  个性化设置

# %% [markdown]
# 上面基于 `option` 的 `pandas` 相关设置是<font color=#E36C07>全局配置</font>，一次设置会在关闭notebook前一直有效
#
# 但相关常用的设置并不多，不能满足更多的个性化需求。
#
# 幸运的是在 `pandas` 中提供 `Styler` 对象让我们进一步个性化展示数据。
#
# 本节我就将一些常用的基于 `style` 个性化设置整理为习题模式方便大家学习、巩固。
#
# 注意：基于 `style` 个性化设置<font color=#E36C07>**同样不会修改数据**</font>，所有 `data.style.xxxx` 输出的数据均是<font color=#E36C07>一次性的（可以复用、导出）</font>，因此你应该在合适的时间选择使用该方法。
#
# 下面仅列举常用的方法，若想了解更多可以查阅[**pandas官方文档对应文章👉**](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)

# %% [markdown]
# ###  重新加载数据

# %% [markdown]
# 为了方便理解，重新读取`data.csv`**前20行指定列**
# - `'positionName'`
# - `'createTime'`（设置为时间格式）
# - `'salary'`
# - `'subwayline'`
# - `'matchScore'`

# %%
data = pd.read_csv(path, usecols=[
                   'positionName', 'createTime', 'salary', 'subwayline', 'matchScore'], nrows=20, parse_dates=['createTime'])

# %%
data
# Out:
#         positionName          createTime  salary subwayline  matchScore
# 0               数据分析 2020-03-16 11:00:00   37500        NaN   15.101875
# 1               数据建模 2020-03-16 11:08:00   15000        NaN   32.559414
# 2               数据分析 2020-03-16 10:33:00    3500        4号线   14.972357
# 3               数据分析 2020-03-16 10:10:00   45000        1号线   12.874153
# 4               数据分析 2020-03-16 09:56:00   30000        NaN   12.755375
# 5               数据分析 2020-03-16 09:54:00   50000        NaN   12.718732
# 6               数据分析 2020-03-16 09:41:00   30000        NaN   12.615116
# 7            数据建模工程师 2020-03-16 11:18:00   35000        2号线    3.033237
# 8             数据分析专家 2020-03-16 10:57:00   60000        NaN    1.141952
# 9              数据分析师 2020-03-16 11:18:00   40000        2号线    1.177361
# 10             数据分析师 2020-03-16 10:57:00   30000        NaN    1.161869
# 11  大数据分析工程师(J11108) 2020-03-16 09:25:00   30000        2号线    4.245066
# 12           数据分析工程师 2020-03-16 11:18:00   20000        2号线    1.091051
# 13           资深数据分析师 2020-03-16 10:57:00   30000        NaN    1.075559
# 14             数据分析师 2020-03-16 10:59:00   37500        NaN    1.053428
# 15       产品运营（偏数据分析） 2020-03-16 10:59:00   27500        NaN    1.015806
# 16       资深数据分析师（杭州） 2020-03-16 10:59:00   37500        NaN    1.009167
# 17           大数据建模总监 2020-03-16 11:08:00   37500        NaN    2.719454
# 18   数据建模专家-杭州-01546 2020-03-16 11:17:00   30000        NaN    3.033237
# 19      数据分析专家（游戏业务） 2020-03-16 10:19:00   37500        2号线    0.834333

# %% [markdown]
# ### 12 隐藏索引
#
# <br>
#
# 隐藏索引列

# %%
bb = data.style.hide_index().set_table_attributes('style="font-size:10px"')
bb
# Out:
# <ipython-input-37-9f1cdae50404>:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   bb = data.style.hide_index().set_table_attributes('style="font-size:10px"')
# <style type="text/css">
# </style>
# <table id="T_6c882" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_6c882_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_6c882_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_6c882_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_6c882_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_6c882_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6c882_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_6c882_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_6c882_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_6c882_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_6c882_row0_col4" class="data row0 col4" >15.101875</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_6c882_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_6c882_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_6c882_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_6c882_row1_col4" class="data row1 col4" >32.559414</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_6c882_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_6c882_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_6c882_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_6c882_row2_col4" class="data row2 col4" >14.972357</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_6c882_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_6c882_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_6c882_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_6c882_row3_col4" class="data row3 col4" >12.874153</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_6c882_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_6c882_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_6c882_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_6c882_row4_col4" class="data row4 col4" >12.755375</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_6c882_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_6c882_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_6c882_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_6c882_row5_col4" class="data row5 col4" >12.718732</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_6c882_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_6c882_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_6c882_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_6c882_row6_col4" class="data row6 col4" >12.615116</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_6c882_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_6c882_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_6c882_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_6c882_row7_col4" class="data row7 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_6c882_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_6c882_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_6c882_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_6c882_row8_col4" class="data row8 col4" >1.141952</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_6c882_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_6c882_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_6c882_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_6c882_row9_col4" class="data row9 col4" >1.177361</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_6c882_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_6c882_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_6c882_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_6c882_row10_col4" class="data row10 col4" >1.161869</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_6c882_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_6c882_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_6c882_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_6c882_row11_col4" class="data row11 col4" >4.245066</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row12_col0" class="data row12 col0" >数据分析工程师</td>
#       <td id="T_6c882_row12_col1" class="data row12 col1" >2020-03-16 11:18:00</td>
#       <td id="T_6c882_row12_col2" class="data row12 col2" >20000</td>
#       <td id="T_6c882_row12_col3" class="data row12 col3" >2号线</td>
#       <td id="T_6c882_row12_col4" class="data row12 col4" >1.091051</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row13_col0" class="data row13 col0" >资深数据分析师</td>
#       <td id="T_6c882_row13_col1" class="data row13 col1" >2020-03-16 10:57:00</td>
#       <td id="T_6c882_row13_col2" class="data row13 col2" >30000</td>
#       <td id="T_6c882_row13_col3" class="data row13 col3" >nan</td>
#       <td id="T_6c882_row13_col4" class="data row13 col4" >1.075559</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row14_col0" class="data row14 col0" >数据分析师</td>
#       <td id="T_6c882_row14_col1" class="data row14 col1" >2020-03-16 10:59:00</td>
#       <td id="T_6c882_row14_col2" class="data row14 col2" >37500</td>
#       <td id="T_6c882_row14_col3" class="data row14 col3" >nan</td>
#       <td id="T_6c882_row14_col4" class="data row14 col4" >1.053428</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row15_col0" class="data row15 col0" >产品运营（偏数据分析）</td>
#       <td id="T_6c882_row15_col1" class="data row15 col1" >2020-03-16 10:59:00</td>
#       <td id="T_6c882_row15_col2" class="data row15 col2" >27500</td>
#       <td id="T_6c882_row15_col3" class="data row15 col3" >nan</td>
#       <td id="T_6c882_row15_col4" class="data row15 col4" >1.015806</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row16_col0" class="data row16 col0" >资深数据分析师（杭州）</td>
#       <td id="T_6c882_row16_col1" class="data row16 col1" >2020-03-16 10:59:00</td>
#       <td id="T_6c882_row16_col2" class="data row16 col2" >37500</td>
#       <td id="T_6c882_row16_col3" class="data row16 col3" >nan</td>
#       <td id="T_6c882_row16_col4" class="data row16 col4" >1.009167</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row17_col0" class="data row17 col0" >大数据建模总监</td>
#       <td id="T_6c882_row17_col1" class="data row17 col1" >2020-03-16 11:08:00</td>
#       <td id="T_6c882_row17_col2" class="data row17 col2" >37500</td>
#       <td id="T_6c882_row17_col3" class="data row17 col3" >nan</td>
#       <td id="T_6c882_row17_col4" class="data row17 col4" >2.719454</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row18_col0" class="data row18 col0" >数据建模专家-杭州-01546</td>
#       <td id="T_6c882_row18_col1" class="data row18 col1" >2020-03-16 11:17:00</td>
#       <td id="T_6c882_row18_col2" class="data row18 col2" >30000</td>
#       <td id="T_6c882_row18_col3" class="data row18 col3" >nan</td>
#       <td id="T_6c882_row18_col4" class="data row18 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <td id="T_6c882_row19_col0" class="data row19 col0" >数据分析专家（游戏业务）</td>
#       <td id="T_6c882_row19_col1" class="data row19 col1" >2020-03-16 10:19:00</td>
#       <td id="T_6c882_row19_col2" class="data row19 c

# %%
# Styler.hide(axis = "index")
# data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-49539e2dac2f> in <cell line: 1>()
# ----> 1 Styler.hide(axis = "index")
#       2 data
#
# NameError: name 'Styler' is not defined

# %% [markdown]
# ### 13 调整精度
#
# <br>
#
# 将带有小数点的列精度调整为小数点后2位

# %%
# data.style.set_precision(2).set_table_attributes('style="font-size:10px"')
# data

ss = data.style.format(precision=2)
ss
# Out:
# <style type="text/css">
# </style>
# <table id="T_6d9ab" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d9ab_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_6d9ab_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_6d9ab_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_6d9ab_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_6d9ab_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d9ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d9ab_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_6d9ab_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_6d9ab_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_6d9ab_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_6d9ab_row0_col4" class="data row0 col4" >15.10</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6d9ab_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_6d9ab_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_6d9ab_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_6d9ab_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_6d9ab_row1_col4" class="data row1 col4" >32.56</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6d9ab_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_6d9ab_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_6d9ab_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_6d9ab_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_6d9ab_row2_col4" class="data row2 col4" >14.97</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6d9ab_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_6d9ab_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_6d9ab_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_6d9ab_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_6d9ab_row3_col4" class="data row3 col4" >12.87</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6d9ab_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_6d9ab_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_6d9ab_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_6d9ab_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_6d9ab_row4_col4" class="data row4 col4" >12.76</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6d9ab_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_6d9ab_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_6d9ab_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_6d9ab_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_6d9ab_row5_col4" class="data row5 col4" >12.72</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6d9ab_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_6d9ab_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_6d9ab_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_6d9ab_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_6d9ab_row6_col4" class="data row6 col4" >12.62</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6d9ab_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_6d9ab_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_6d9ab_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_6d9ab_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_6d9ab_row7_col4" class="data row7 col4" >3.03</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6d9ab_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_6d9ab_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_6d9ab_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_6d9ab_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_6d9ab_row8_col4" class="data row8 col4" >1.14</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6d9ab_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_6d9ab_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_6d9ab_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_6d9ab_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_6d9ab_row9_col4" class="data row9 col4" >1.18</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6d9ab_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_6d9ab_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_6d9ab_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_6d9ab_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_6d9ab_row10_col4" class="data row10 col4" >1.16</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6d9ab_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_6d9ab_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_6d9ab_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_6d9ab_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_6d9ab_row11_col4" class="data row11 col4" >4.25</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6d9ab_row12_col0" class="data row12 col0" >数据分析工程师</td>
#       <td id="T_6d9ab_row12_col1" class="data row12 col1" >2020-03-16 11:18:00</td>
#       <td id="T_6d9ab_row12_col2" class="data row12 col2" >20000</td>
#       <td id="T_6d9ab_row12_col3" class="data row12 col3" >2号线</td>
#       <td id="T_6d9ab_row12_col4" class="data row12 col4" >1.09</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6d9ab_row13_col0" class="data row13 col0" >资深数据分析师</td>
#       <td id="T_6d9ab_row13_col1" class="data row13 col1" >2020-03-16 10:57:00</td>
#       <td id="T_6d9ab_row13_col2" class="data row13 col2" >30000</td>
#       <td id="T_6d9ab_row13_col3" class="data row13 col3" >nan</td>
#       <td id="T_6d9ab_row13_col4" class="data row13 col4" >1.08</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6d9ab_row14_col0" class="data row14 col0" >数据分析师</td>
#       <td id="T_6d9ab_row14_col1" class="data row14 col1" >2020-03-16 10:59:00</td>
#       <td id="T_6d9ab_row14_col2" class="data row14 col2" >37500</td>
#       <td id="T_6d9ab_row14_col3" class="data row14 col3" >nan</td>
#       <td id="T_6d9ab_row14_col4" class="data row14 col4" >1.05</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6d9ab_row15_col0" class="data row15 col0" >产品运营（偏数据分析）</td>
#       <td id="T_6d9ab_row15_col1" class="data row15 col1" >2020-03-16 10:59:00</td>
#       <td id="T_6d9ab_row15_col2" class="data row15 col2" >27500</td>
#       <td id="T_6d9ab_row15_col3" class="data row15 col3" >nan</td>
#       <td id="T_6d9ab_row15_col4" class="data row15 col4" >1.02</td>
#     </tr>
#     <tr>
#       <th id="T_6d9ab_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6d9ab_row16_col0" class="data row16 col0" >资深数据分析师（杭州）</td>
#       <td id="T_6d9ab_row16_col1

# %% [markdown]
# ### 14 标记缺失值

# %% [markdown]
# 将缺失值标记为`数据缺失`

# %%
cc = data.style.set_na_rep('数据缺失')
cc
# Out:
# <ipython-input-39-ba21594e095a>:1: FutureWarning: this method is deprecated in favour of `Styler.format(na_rep=..)`
#   cc = data.style.set_na_rep('数据缺失')
# <style type="text/css">
# </style>
# <table id="T_0ca99" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ca99_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_0ca99_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_0ca99_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_0ca99_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_0ca99_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ca99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ca99_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_0ca99_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_0ca99_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_0ca99_row0_col3" class="data row0 col3" >数据缺失</td>
#       <td id="T_0ca99_row0_col4" class="data row0 col4" >15.101875</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ca99_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_0ca99_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_0ca99_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_0ca99_row1_col3" class="data row1 col3" >数据缺失</td>
#       <td id="T_0ca99_row1_col4" class="data row1 col4" >32.559414</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0ca99_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_0ca99_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_0ca99_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_0ca99_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_0ca99_row2_col4" class="data row2 col4" >14.972357</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0ca99_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_0ca99_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_0ca99_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_0ca99_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_0ca99_row3_col4" class="data row3 col4" >12.874153</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0ca99_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_0ca99_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_0ca99_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_0ca99_row4_col3" class="data row4 col3" >数据缺失</td>
#       <td id="T_0ca99_row4_col4" class="data row4 col4" >12.755375</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0ca99_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_0ca99_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_0ca99_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_0ca99_row5_col3" class="data row5 col3" >数据缺失</td>
#       <td id="T_0ca99_row5_col4" class="data row5 col4" >12.718732</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0ca99_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_0ca99_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_0ca99_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_0ca99_row6_col3" class="data row6 col3" >数据缺失</td>
#       <td id="T_0ca99_row6_col4" class="data row6 col4" >12.615116</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0ca99_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_0ca99_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_0ca99_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_0ca99_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_0ca99_row7_col4" class="data row7 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0ca99_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_0ca99_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_0ca99_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_0ca99_row8_col3" class="data row8 col3" >数据缺失</td>
#       <td id="T_0ca99_row8_col4" class="data row8 col4" >1.141952</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0ca99_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_0ca99_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_0ca99_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_0ca99_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_0ca99_row9_col4" class="data row9 col4" >1.177361</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0ca99_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_0ca99_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_0ca99_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_0ca99_row10_col3" class="data row10 col3" >数据缺失</td>
#       <td id="T_0ca99_row10_col4" class="data row10 col4" >1.161869</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0ca99_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_0ca99_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_0ca99_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_0ca99_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_0ca99_row11_col4" class="data row11 col4" >4.245066</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0ca99_row12_col0" class="data row12 col0" >数据分析工程师</td>
#       <td id="T_0ca99_row12_col1" class="data row12 col1" >2020-03-16 11:18:00</td>
#       <td id="T_0ca99_row12_col2" class="data row12 col2" >20000</td>
#       <td id="T_0ca99_row12_col3" class="data row12 col3" >2号线</td>
#       <td id="T_0ca99_row12_col4" class="data row12 col4" >1.091051</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0ca99_row13_col0" class="data row13 col0" >资深数据分析师</td>
#       <td id="T_0ca99_row13_col1" class="data row13 col1" >2020-03-16 10:57:00</td>
#       <td id="T_0ca99_row13_col2" class="data row13 col2" >30000</td>
#       <td id="T_0ca99_row13_col3" class="data row13 col3" >数据缺失</td>
#       <td id="T_0ca99_row13_col4" class="data row13 col4" >1.075559</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0ca99_row14_col0" class="data row14 col0" >数据分析师</td>
#       <td id="T_0ca99_row14_col1" class="data row14 col1" >2020-03-16 10:59:00</td>
#       <td id="T_0ca99_row14_col2" class="data row14 col2" >37500</td>
#       <td id="T_0ca99_row14_col3" class="data row14 col3" >数据缺失</td>
#       <td id="T_0ca99_row14_col4" class="data row14 col4" >1.053428</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0ca99_row15_col0" class="data row15 col0" >产品运营（偏数据分析）</td>
#       <td id="T_0ca99_row15_col1" class="data row15 col1" >2020-03-16 10:59:00</td>
#       <td id="T_0ca99_row15_col2" class="data row15 col2" >27500</td>
#       <td id="T_0ca99_row15_col3" class="data row15 col3" >数据缺失</td>
#       <td id="T_0ca99_row15_col4" class="data row15 col4" >1.015806</td>
#     </tr>
#     <tr>
#       <th id="T_0ca99_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0ca99_row16_col0"

# %% [markdown]
# 微信搜索公众号「早起Python」，关注后可以获得更多资源！

# %% [markdown]
# ### 15 高亮缺失值
#
# <br>
#
# 将缺失值高亮，颜色名`skyblue`

# %%
dd = data.style.set_na_rep('数据缺失').highlight_null(null_color='skyblue')
dd
# Out:
# <ipython-input-40-d379443d2ce6>:1: FutureWarning: this method is deprecated in favour of `Styler.format(na_rep=..)`
#   dd = data.style.set_na_rep('数据缺失').highlight_null(null_color='skyblue')
# <ipython-input-40-d379443d2ce6>:1: FutureWarning: `null_color` is deprecated: use `color` instead
#   dd = data.style.set_na_rep('数据缺失').highlight_null(null_color='skyblue')
# <style type="text/css">
# #T_cfad9_row0_col3, #T_cfad9_row1_col3, #T_cfad9_row4_col3, #T_cfad9_row5_col3, #T_cfad9_row6_col3, #T_cfad9_row8_col3, #T_cfad9_row10_col3, #T_cfad9_row13_col3, #T_cfad9_row14_col3, #T_cfad9_row15_col3, #T_cfad9_row16_col3, #T_cfad9_row17_col3, #T_cfad9_row18_col3 {
#   background-color: skyblue;
# }
# </style>
# <table id="T_cfad9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfad9_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_cfad9_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_cfad9_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_cfad9_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_cfad9_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfad9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cfad9_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_cfad9_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_cfad9_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_cfad9_row0_col3" class="data row0 col3" >数据缺失</td>
#       <td id="T_cfad9_row0_col4" class="data row0 col4" >15.101875</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cfad9_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_cfad9_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_cfad9_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_cfad9_row1_col3" class="data row1 col3" >数据缺失</td>
#       <td id="T_cfad9_row1_col4" class="data row1 col4" >32.559414</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cfad9_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_cfad9_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_cfad9_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_cfad9_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_cfad9_row2_col4" class="data row2 col4" >14.972357</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cfad9_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_cfad9_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_cfad9_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_cfad9_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_cfad9_row3_col4" class="data row3 col4" >12.874153</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cfad9_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_cfad9_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_cfad9_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_cfad9_row4_col3" class="data row4 col3" >数据缺失</td>
#       <td id="T_cfad9_row4_col4" class="data row4 col4" >12.755375</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cfad9_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_cfad9_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_cfad9_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_cfad9_row5_col3" class="data row5 col3" >数据缺失</td>
#       <td id="T_cfad9_row5_col4" class="data row5 col4" >12.718732</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cfad9_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_cfad9_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_cfad9_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_cfad9_row6_col3" class="data row6 col3" >数据缺失</td>
#       <td id="T_cfad9_row6_col4" class="data row6 col4" >12.615116</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cfad9_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_cfad9_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_cfad9_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_cfad9_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_cfad9_row7_col4" class="data row7 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cfad9_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_cfad9_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_cfad9_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_cfad9_row8_col3" class="data row8 col3" >数据缺失</td>
#       <td id="T_cfad9_row8_col4" class="data row8 col4" >1.141952</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cfad9_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_cfad9_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_cfad9_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_cfad9_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_cfad9_row9_col4" class="data row9 col4" >1.177361</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cfad9_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_cfad9_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_cfad9_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_cfad9_row10_col3" class="data row10 col3" >数据缺失</td>
#       <td id="T_cfad9_row10_col4" class="data row10 col4" >1.161869</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cfad9_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_cfad9_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_cfad9_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_cfad9_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_cfad9_row11_col4" class="data row11 col4" >4.245066</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cfad9_row12_col0" class="data row12 col0" >数据分析工程师</td>
#       <td id="T_cfad9_row12_col1" class="data row12 col1" >2020-03-16 11:18:00</td>
#       <td id="T_cfad9_row12_col2" class="data row12 col2" >20000</td>
#       <td id="T_cfad9_row12_col3" class="data row12 col3" >2号线</td>
#       <td id="T_cfad9_row12_col4" class="data row12 col4" >1.091051</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cfad9_row13_col0" class="data row13 col0" >资深数据分析师</td>
#       <td id="T_cfad9_row13_col1" class="data row13 col1" >2020-03-16 10:57:00</td>
#       <td id="T_cfad9_row13_col2" class="data row13 col2" >30000</td>
#       <td id="T_cfad9_row13_col3" class="data row13 col3" >数据缺失</td>
#       <td id="T_cfad9_row13_col4" class="data row13 col4" >1.075559</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cfad9_row14_col0" class="data row14 col0" >数据分析师</td>
#       <td id="T_cfad9_row14_col1" class="data row14 col1" >2020-03-16 10:59:00</td>
#       <td id="T_cfad9_row14_col2" class="data row14 col2" >37500</td>
#       <td id="T_cfad9_row14_col3" class="data row14 col3" >数据缺失</td>
#       <td id="T_cfad9_row14_col4" class="data row14 col4" >1.053428</td>
#     </tr>
#     <tr>
#       <th id="T_cfad9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cfad9_row15_col0" class="data row15 col0" >产品运营（偏数据分析）</td>
#       <td id="T_cfad9_row15_col1" class="data row15 col1" >2020-03-16 10:59:00</td>
#       <td id="T_cfad9_row15_col2" class="dat

# %% [markdown]
# ### 16 高亮数值列最大值
# <br>
# 将 数值格式列的最大值进行高亮

# %%
ee = data.style.highlight_max(['matchScore','salary'])
ee
# Out:
# <style type="text/css">
# #T_425ca_row1_col4, #T_425ca_row8_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_425ca" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_425ca_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_425ca_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_425ca_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_425ca_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_425ca_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_425ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_425ca_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_425ca_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_425ca_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_425ca_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_425ca_row0_col4" class="data row0 col4" >15.101875</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_425ca_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_425ca_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_425ca_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_425ca_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_425ca_row1_col4" class="data row1 col4" >32.559414</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_425ca_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_425ca_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_425ca_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_425ca_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_425ca_row2_col4" class="data row2 col4" >14.972357</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_425ca_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_425ca_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_425ca_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_425ca_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_425ca_row3_col4" class="data row3 col4" >12.874153</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_425ca_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_425ca_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_425ca_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_425ca_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_425ca_row4_col4" class="data row4 col4" >12.755375</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_425ca_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_425ca_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_425ca_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_425ca_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_425ca_row5_col4" class="data row5 col4" >12.718732</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_425ca_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_425ca_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_425ca_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_425ca_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_425ca_row6_col4" class="data row6 col4" >12.615116</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_425ca_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_425ca_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_425ca_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_425ca_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_425ca_row7_col4" class="data row7 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_425ca_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_425ca_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_425ca_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_425ca_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_425ca_row8_col4" class="data row8 col4" >1.141952</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_425ca_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_425ca_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_425ca_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_425ca_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_425ca_row9_col4" class="data row9 col4" >1.177361</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_425ca_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_425ca_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_425ca_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_425ca_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_425ca_row10_col4" class="data row10 col4" >1.161869</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_425ca_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_425ca_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_425ca_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_425ca_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_425ca_row11_col4" class="data row11 col4" >4.245066</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_425ca_row12_col0" class="data row12 col0" >数据分析工程师</td>
#       <td id="T_425ca_row12_col1" class="data row12 col1" >2020-03-16 11:18:00</td>
#       <td id="T_425ca_row12_col2" class="data row12 col2" >20000</td>
#       <td id="T_425ca_row12_col3" class="data row12 col3" >2号线</td>
#       <td id="T_425ca_row12_col4" class="data row12 col4" >1.091051</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_425ca_row13_col0" class="data row13 col0" >资深数据分析师</td>
#       <td id="T_425ca_row13_col1" class="data row13 col1" >2020-03-16 10:57:00</td>
#       <td id="T_425ca_row13_col2" class="data row13 col2" >30000</td>
#       <td id="T_425ca_row13_col3" class="data row13 col3" >nan</td>
#       <td id="T_425ca_row13_col4" class="data row13 col4" >1.075559</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_425ca_row14_col0" class="data row14 col0" >数据分析师</td>
#       <td id="T_425ca_row14_col1" class="data row14 col1" >2020-03-16 10:59:00</td>
#       <td id="T_425ca_row14_col2" class="data row14 col2" >37500</td>
#       <td id="T_425ca_row14_col3" class="data row14 col3" >nan</td>
#       <td id="T_425ca_row14_col4" class="data row14 col4" >1.053428</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_425ca_row15_col0" class="data row15 col0" >产品运营（偏数据分析）</td>
#       <td id="T_425ca_row15_col1" class="data row15 col1" >2020-03-16 10:59:00</td>
#       <td id="T_425ca_row15_col2" class="data row15 col2" >27500</td>
#       <td id="T_425ca_row15_col3" class="data row15 col3" >nan</td>
#       <td id="T_425ca_row15_col4" class="data row15 col4" >1.015806</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row16" class="row_head

# %% [markdown]
# ### 17 高亮数值列最小值
# <br>
# 将 数值格式列的最小值进行高亮

# %%
ff = data.style.highlight_min(['matchScore','salary'])
ff
# Out:
# <style type="text/css">
# #T_ec913_row2_col2, #T_ec913_row19_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_ec913" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec913_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_ec913_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_ec913_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_ec913_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_ec913_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec913_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec913_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_ec913_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_ec913_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_ec913_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_ec913_row0_col4" class="data row0 col4" >15.101875</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec913_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_ec913_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_ec913_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_ec913_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_ec913_row1_col4" class="data row1 col4" >32.559414</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec913_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_ec913_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_ec913_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_ec913_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_ec913_row2_col4" class="data row2 col4" >14.972357</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec913_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_ec913_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_ec913_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_ec913_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_ec913_row3_col4" class="data row3 col4" >12.874153</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec913_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_ec913_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_ec913_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_ec913_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_ec913_row4_col4" class="data row4 col4" >12.755375</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ec913_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_ec913_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_ec913_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_ec913_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_ec913_row5_col4" class="data row5 col4" >12.718732</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ec913_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_ec913_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_ec913_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_ec913_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_ec913_row6_col4" class="data row6 col4" >12.615116</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ec913_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_ec913_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_ec913_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_ec913_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_ec913_row7_col4" class="data row7 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ec913_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_ec913_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_ec913_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_ec913_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_ec913_row8_col4" class="data row8 col4" >1.141952</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ec913_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_ec913_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_ec913_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_ec913_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_ec913_row9_col4" class="data row9 col4" >1.177361</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ec913_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_ec913_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_ec913_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_ec913_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_ec913_row10_col4" class="data row10 col4" >1.161869</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ec913_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_ec913_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_ec913_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_ec913_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_ec913_row11_col4" class="data row11 col4" >4.245066</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ec913_row12_col0" class="data row12 col0" >数据分析工程师</td>
#       <td id="T_ec913_row12_col1" class="data row12 col1" >2020-03-16 11:18:00</td>
#       <td id="T_ec913_row12_col2" class="data row12 col2" >20000</td>
#       <td id="T_ec913_row12_col3" class="data row12 col3" >2号线</td>
#       <td id="T_ec913_row12_col4" class="data row12 col4" >1.091051</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ec913_row13_col0" class="data row13 col0" >资深数据分析师</td>
#       <td id="T_ec913_row13_col1" class="data row13 col1" >2020-03-16 10:57:00</td>
#       <td id="T_ec913_row13_col2" class="data row13 col2" >30000</td>
#       <td id="T_ec913_row13_col3" class="data row13 col3" >nan</td>
#       <td id="T_ec913_row13_col4" class="data row13 col4" >1.075559</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ec913_row14_col0" class="data row14 col0" >数据分析师</td>
#       <td id="T_ec913_row14_col1" class="data row14 col1" >2020-03-16 10:59:00</td>
#       <td id="T_ec913_row14_col2" class="data row14 col2" >37500</td>
#       <td id="T_ec913_row14_col3" class="data row14 col3" >nan</td>
#       <td id="T_ec913_row14_col4" class="data row14 col4" >1.053428</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ec913_row15_col0" class="data row15 col0" >产品运营（偏数据分析）</td>
#       <td id="T_ec913_row15_col1" class="data row15 col1" >2020-03-16 10:59:00</td>
#       <td id="T_ec913_row15_col2" class="data row15 col2" >27500</td>
#       <td id="T_ec913_row15_col3" class="data row15 col3" >nan</td>
#       <td id="T_ec913_row15_col4" class="data row15 col4" >1.015806</td>
#     </tr>
#     <tr>
#       <th id="T_ec913_level0_row16" class="row_hea

# %% [markdown]
# ### 18 同时高亮最大最小值
#
# <br>
#
# 同时高亮最大值（颜色代码为`#F77802`）与最小值（颜色代码为`#26BE49`）

# %%
gg = data.style.highlight_min(['matchScore','salary'],color='#26BE49').highlight_max(['matchScore','salary'],color='#F77802')
gg
# Out:
# <style type="text/css">
# #T_d7ce6_row1_col4, #T_d7ce6_row8_col2 {
#   background-color: #F77802;
# }
# #T_d7ce6_row2_col2, #T_d7ce6_row19_col4 {
#   background-color: #26BE49;
# }
# </style>
# <table id="T_d7ce6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7ce6_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_d7ce6_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_d7ce6_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_d7ce6_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_d7ce6_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7ce6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7ce6_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_d7ce6_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_d7ce6_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_d7ce6_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_d7ce6_row0_col4" class="data row0 col4" >15.101875</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7ce6_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_d7ce6_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_d7ce6_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_d7ce6_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_d7ce6_row1_col4" class="data row1 col4" >32.559414</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d7ce6_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_d7ce6_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_d7ce6_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_d7ce6_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_d7ce6_row2_col4" class="data row2 col4" >14.972357</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d7ce6_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_d7ce6_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_d7ce6_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_d7ce6_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_d7ce6_row3_col4" class="data row3 col4" >12.874153</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d7ce6_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_d7ce6_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_d7ce6_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_d7ce6_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_d7ce6_row4_col4" class="data row4 col4" >12.755375</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d7ce6_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_d7ce6_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_d7ce6_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_d7ce6_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_d7ce6_row5_col4" class="data row5 col4" >12.718732</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d7ce6_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_d7ce6_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_d7ce6_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_d7ce6_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_d7ce6_row6_col4" class="data row6 col4" >12.615116</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d7ce6_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_d7ce6_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_d7ce6_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_d7ce6_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_d7ce6_row7_col4" class="data row7 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d7ce6_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_d7ce6_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_d7ce6_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_d7ce6_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_d7ce6_row8_col4" class="data row8 col4" >1.141952</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d7ce6_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_d7ce6_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_d7ce6_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_d7ce6_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_d7ce6_row9_col4" class="data row9 col4" >1.177361</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d7ce6_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_d7ce6_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_d7ce6_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_d7ce6_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_d7ce6_row10_col4" class="data row10 col4" >1.161869</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d7ce6_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_d7ce6_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_d7ce6_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_d7ce6_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_d7ce6_row11_col4" class="data row11 col4" >4.245066</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d7ce6_row12_col0" class="data row12 col0" >数据分析工程师</td>
#       <td id="T_d7ce6_row12_col1" class="data row12 col1" >2020-03-16 11:18:00</td>
#       <td id="T_d7ce6_row12_col2" class="data row12 col2" >20000</td>
#       <td id="T_d7ce6_row12_col3" class="data row12 col3" >2号线</td>
#       <td id="T_d7ce6_row12_col4" class="data row12 col4" >1.091051</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d7ce6_row13_col0" class="data row13 col0" >资深数据分析师</td>
#       <td id="T_d7ce6_row13_col1" class="data row13 col1" >2020-03-16 10:57:00</td>
#       <td id="T_d7ce6_row13_col2" class="data row13 col2" >30000</td>
#       <td id="T_d7ce6_row13_col3" class="data row13 col3" >nan</td>
#       <td id="T_d7ce6_row13_col4" class="data row13 col4" >1.075559</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d7ce6_row14_col0" class="data row14 col0" >数据分析师</td>
#       <td id="T_d7ce6_row14_col1" class="data row14 col1" >2020-03-16 10:59:00</td>
#       <td id="T_d7ce6_row14_col2" class="data row14 col2" >37500</td>
#       <td id="T_d7ce6_row14_col3" class="data row14 col3" >nan</td>
#       <td id="T_d7ce6_row14_col4" class="data row14 col4" >1.053428</td>
#     </tr>
#     <tr>
#       <th id="T_d7ce6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d7ce6_row15_col0" class="data row15 col0" >产品运营（偏数据分析）</td>
#       <td id="T_d7ce6_row15_col1" class="data row15 col1" >2020-03-16 10:59:00</td>
#       <td id="T_d7ce6_row15_col2" class="data row15 col2" >27500</td>
#       <td id="T_d7ce6_row15_col3" class="data row15 col3" >nan</td>
#       <td id="T_d7ce6_row15_col4" class="data row15 col4" >1.015806</

# %% [markdown]
# ### 19 指定格式高亮

# %% [markdown]
# 高亮 `salary` 列范围在 3000 - 10000 的数值

# %%
hh = data.style.highlight_between('salary', left=3000, right=20000)
hh
# Out:
# <style type="text/css">
# #T_b4bfe_row1_col2, #T_b4bfe_row2_col2, #T_b4bfe_row12_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b4bfe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4bfe_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_b4bfe_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_b4bfe_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_b4bfe_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_b4bfe_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4bfe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4bfe_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_b4bfe_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_b4bfe_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_b4bfe_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_b4bfe_row0_col4" class="data row0 col4" >15.101875</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4bfe_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_b4bfe_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_b4bfe_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_b4bfe_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_b4bfe_row1_col4" class="data row1 col4" >32.559414</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4bfe_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_b4bfe_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_b4bfe_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_b4bfe_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_b4bfe_row2_col4" class="data row2 col4" >14.972357</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b4bfe_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_b4bfe_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_b4bfe_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_b4bfe_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_b4bfe_row3_col4" class="data row3 col4" >12.874153</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b4bfe_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_b4bfe_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_b4bfe_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_b4bfe_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_b4bfe_row4_col4" class="data row4 col4" >12.755375</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b4bfe_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_b4bfe_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_b4bfe_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_b4bfe_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_b4bfe_row5_col4" class="data row5 col4" >12.718732</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b4bfe_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_b4bfe_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_b4bfe_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_b4bfe_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_b4bfe_row6_col4" class="data row6 col4" >12.615116</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b4bfe_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_b4bfe_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_b4bfe_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_b4bfe_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_b4bfe_row7_col4" class="data row7 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b4bfe_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_b4bfe_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_b4bfe_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_b4bfe_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_b4bfe_row8_col4" class="data row8 col4" >1.141952</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b4bfe_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_b4bfe_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_b4bfe_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_b4bfe_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_b4bfe_row9_col4" class="data row9 col4" >1.177361</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b4bfe_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_b4bfe_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_b4bfe_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_b4bfe_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_b4bfe_row10_col4" class="data row10 col4" >1.161869</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b4bfe_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_b4bfe_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_b4bfe_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_b4bfe_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_b4bfe_row11_col4" class="data row11 col4" >4.245066</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b4bfe_row12_col0" class="data row12 col0" >数据分析工程师</td>
#       <td id="T_b4bfe_row12_col1" class="data row12 col1" >2020-03-16 11:18:00</td>
#       <td id="T_b4bfe_row12_col2" class="data row12 col2" >20000</td>
#       <td id="T_b4bfe_row12_col3" class="data row12 col3" >2号线</td>
#       <td id="T_b4bfe_row12_col4" class="data row12 col4" >1.091051</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b4bfe_row13_col0" class="data row13 col0" >资深数据分析师</td>
#       <td id="T_b4bfe_row13_col1" class="data row13 col1" >2020-03-16 10:57:00</td>
#       <td id="T_b4bfe_row13_col2" class="data row13 col2" >30000</td>
#       <td id="T_b4bfe_row13_col3" class="data row13 col3" >nan</td>
#       <td id="T_b4bfe_row13_col4" class="data row13 col4" >1.075559</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b4bfe_row14_col0" class="data row14 col0" >数据分析师</td>
#       <td id="T_b4bfe_row14_col1" class="data row14 col1" >2020-03-16 10:59:00</td>
#       <td id="T_b4bfe_row14_col2" class="data row14 col2" >37500</td>
#       <td id="T_b4bfe_row14_col3" class="data row14 col3" >nan</td>
#       <td id="T_b4bfe_row14_col4" class="data row14 col4" >1.053428</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b4bfe_row15_col0" class="data row15 col0" >产品运营（偏数据分析）</td>
#       <td id="T_b4bfe_row15_col1" class="data row15 col1" >2020-03-16 10:59:00</td>
#       <td id="T_b4bfe_row15_col2" class="data row15 col2" >27500</td>
#       <td id="T_b4bfe_row15_col3" class="data row15 col3" >nan</td>
#       <td id="T_b4bfe_row15_col4" class="data row15 col4" >1.015806</td>
#     </tr>
#     <tr>
#       <th id="T_b4bfe_level0_r

# %% [markdown]
# ### 20 渐变显示数值列

# %% [markdown]
# 将数值格式的列使用渐变色（绿色）进行显示，以突出趋势

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)
ii = data.style.background_gradient(cmap=cm)
ii
# Out:
# <style type="text/css">
# #T_c09c6_row0_col2, #T_c09c6_row14_col2, #T_c09c6_row16_col2, #T_c09c6_row17_col2, #T_c09c6_row19_col2 {
#   background-color: #5dae5d;
#   color: #f1f1f1;
# }
# #T_c09c6_row0_col4 {
#   background-color: #81bf81;
#   color: #000000;
# }
# #T_c09c6_row1_col2 {
#   background-color: #bbdcbb;
#   color: #000000;
# }
# #T_c09c6_row1_col4, #T_c09c6_row8_col2 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_c09c6_row2_col2, #T_c09c6_row19_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_c09c6_row2_col4 {
#   background-color: #82c082;
#   color: #000000;
# }
# #T_c09c6_row3_col2 {
#   background-color: #3e9e3e;
#   color: #f1f1f1;
# }
# #T_c09c6_row3_col4 {
#   background-color: #91c791;
#   color: #000000;
# }
# #T_c09c6_row4_col2, #T_c09c6_row6_col2, #T_c09c6_row10_col2, #T_c09c6_row11_col2, #T_c09c6_row13_col2, #T_c09c6_row18_col2 {
#   background-color: #7cbd7c;
#   color: #000000;
# }
# #T_c09c6_row4_col4 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_c09c6_row5_col2 {
#   background-color: #299429;
#   color: #f1f1f1;
# }
# #T_c09c6_row5_col4, #T_c09c6_row6_col4 {
#   background-color: #93c893;
#   color: #000000;
# }
# #T_c09c6_row7_col2 {
#   background-color: #68b368;
#   color: #f1f1f1;
# }
# #T_c09c6_row7_col4, #T_c09c6_row18_col4 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_c09c6_row8_col4, #T_c09c6_row9_col4, #T_c09c6_row10_col4, #T_c09c6_row12_col4 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_c09c6_row9_col2 {
#   background-color: #53a953;
#   color: #f1f1f1;
# }
# #T_c09c6_row11_col4 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_c09c6_row12_col2 {
#   background-color: #a6d2a6;
#   color: #000000;
# }
# #T_c09c6_row13_col4, #T_c09c6_row14_col4, #T_c09c6_row15_col4, #T_c09c6_row16_col4 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_c09c6_row15_col2 {
#   background-color: #87c287;
#   color: #000000;
# }
# #T_c09c6_row17_col4 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# </style>
# <table id="T_c09c6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c09c6_level0_col0" class="col_heading level0 col0" >positionName</th>
#       <th id="T_c09c6_level0_col1" class="col_heading level0 col1" >createTime</th>
#       <th id="T_c09c6_level0_col2" class="col_heading level0 col2" >salary</th>
#       <th id="T_c09c6_level0_col3" class="col_heading level0 col3" >subwayline</th>
#       <th id="T_c09c6_level0_col4" class="col_heading level0 col4" >matchScore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c09c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c09c6_row0_col0" class="data row0 col0" >数据分析</td>
#       <td id="T_c09c6_row0_col1" class="data row0 col1" >2020-03-16 11:00:00</td>
#       <td id="T_c09c6_row0_col2" class="data row0 col2" >37500</td>
#       <td id="T_c09c6_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_c09c6_row0_col4" class="data row0 col4" >15.101875</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c09c6_row1_col0" class="data row1 col0" >数据建模</td>
#       <td id="T_c09c6_row1_col1" class="data row1 col1" >2020-03-16 11:08:00</td>
#       <td id="T_c09c6_row1_col2" class="data row1 col2" >15000</td>
#       <td id="T_c09c6_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_c09c6_row1_col4" class="data row1 col4" >32.559414</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c09c6_row2_col0" class="data row2 col0" >数据分析</td>
#       <td id="T_c09c6_row2_col1" class="data row2 col1" >2020-03-16 10:33:00</td>
#       <td id="T_c09c6_row2_col2" class="data row2 col2" >3500</td>
#       <td id="T_c09c6_row2_col3" class="data row2 col3" >4号线</td>
#       <td id="T_c09c6_row2_col4" class="data row2 col4" >14.972357</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c09c6_row3_col0" class="data row3 col0" >数据分析</td>
#       <td id="T_c09c6_row3_col1" class="data row3 col1" >2020-03-16 10:10:00</td>
#       <td id="T_c09c6_row3_col2" class="data row3 col2" >45000</td>
#       <td id="T_c09c6_row3_col3" class="data row3 col3" >1号线</td>
#       <td id="T_c09c6_row3_col4" class="data row3 col4" >12.874153</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c09c6_row4_col0" class="data row4 col0" >数据分析</td>
#       <td id="T_c09c6_row4_col1" class="data row4 col1" >2020-03-16 09:56:00</td>
#       <td id="T_c09c6_row4_col2" class="data row4 col2" >30000</td>
#       <td id="T_c09c6_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_c09c6_row4_col4" class="data row4 col4" >12.755375</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c09c6_row5_col0" class="data row5 col0" >数据分析</td>
#       <td id="T_c09c6_row5_col1" class="data row5 col1" >2020-03-16 09:54:00</td>
#       <td id="T_c09c6_row5_col2" class="data row5 col2" >50000</td>
#       <td id="T_c09c6_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_c09c6_row5_col4" class="data row5 col4" >12.718732</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c09c6_row6_col0" class="data row6 col0" >数据分析</td>
#       <td id="T_c09c6_row6_col1" class="data row6 col1" >2020-03-16 09:41:00</td>
#       <td id="T_c09c6_row6_col2" class="data row6 col2" >30000</td>
#       <td id="T_c09c6_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_c09c6_row6_col4" class="data row6 col4" >12.615116</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c09c6_row7_col0" class="data row7 col0" >数据建模工程师</td>
#       <td id="T_c09c6_row7_col1" class="data row7 col1" >2020-03-16 11:18:00</td>
#       <td id="T_c09c6_row7_col2" class="data row7 col2" >35000</td>
#       <td id="T_c09c6_row7_col3" class="data row7 col3" >2号线</td>
#       <td id="T_c09c6_row7_col4" class="data row7 col4" >3.033237</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c09c6_row8_col0" class="data row8 col0" >数据分析专家</td>
#       <td id="T_c09c6_row8_col1" class="data row8 col1" >2020-03-16 10:57:00</td>
#       <td id="T_c09c6_row8_col2" class="data row8 col2" >60000</td>
#       <td id="T_c09c6_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_c09c6_row8_col4" class="data row8 col4" >1.141952</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c09c6_row9_col0" class="data row9 col0" >数据分析师</td>
#       <td id="T_c09c6_row9_col1" class="data row9 col1" >2020-03-16 11:18:00</td>
#       <td id="T_c09c6_row9_col2" class="data row9 col2" >40000</td>
#       <td id="T_c09c6_row9_col3" class="data row9 col3" >2号线</td>
#       <td id="T_c09c6_row9_col4" class="data row9 col4" >1.177361</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c09c6_row10_col0" class="data row10 col0" >数据分析师</td>
#       <td id="T_c09c6_row10_col1" class="data row10 col1" >2020-03-16 10:57:00</td>
#       <td id="T_c09c6_row10_col2" class="data row10 col2" >30000</td>
#       <td id="T_c09c6_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_c09c6_row10_col4" class="data row10 col4" >1.161869</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c09c6_row11_col0" class="data row11 col0" >大数据分析工程师(J11108)</td>
#       <td id="T_c09c6_row11_col1" class="data row11 col1" >2020-03-16 09:25:00</td>
#       <td id="T_c09c6_row11_col2" class="data row11 col2" >30000</td>
#       <td id="T_c09c6_row11_col3" class="data row11 col3" >2号线</td>
#       <td id="T_c09c6_row11_col4" class="data row11 col4" >4.245066</td>
#     </tr>
#     <tr>
#       <th id="T_c09c6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c09c6_row12_col0

# %% [markdown]
# ### 21 修改字体颜色
#
# <br>
#
# 将 `salary` 列修改为红色字体

# %% [markdown]
# ### 22 修改背景颜色、对齐方式、字体大小
# <br>
#
# 将整个 `dataframe` 进行如下设置：
# - 居中
# - 背景色修改为 `#F8F8FF`
# - 字体:13px

# %% [markdown]
# ### 23 综合(链式)设置
# <br>
#
# 除了上面的单个设置，还可以将多个设置进行结合，下面对整个 `dataframe` 进行如下设置：
# - 居中
# - 背景色修改为 `#F8F8FF`
# - 字体:13px
#
# 并将 `salary` 列字体修改为红色

# %% [markdown]
# ### 24 导出样式

# %% [markdown]
# 将上一题带有样式的 `pandas` 数据框导出为本地 Excel(`.xlsx`格式)

# %% [markdown]
# ### 25 制作指定列条形图
#
# <br>
#
# 在 `pandas` 中对 `salary` 列使用条形图进行可视化，指定颜色`skyblue`

# %% [markdown]
# ### 26 带有条件的样式（自定义样式）

# %% [markdown]
# 将 `salary` 列数值大于 30000 的单元格字体修改为红色

# %% [markdown]
# ### 27 格式化输出日期类型
#
# <br>
#
# 将 `createTime` 列格式化输出为 `xx年xx月xx日`

# %% [markdown]
# ### 28 指定（自定义）格式化数据
#
# <br>
#
# - 在 `salary` 列后增加"元"
# - 对 `matchScore` 列保留两位小数并增加"分"

# %% [markdown]
# ![](http://liuzaoqi.oss-cn-beijing.aliyuncs.com/2021/09/16/16317972442543.jpg?域名/sample.jpg?x-oss-process=style/stylename)
